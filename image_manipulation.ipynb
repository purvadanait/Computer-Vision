# %%
from PIL import Image
from PIL import ImageOps
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
image = Image.open(r"C:\Users\Lenovo\OneDrive\Desktop\f56d42ed91044f4b2e13746e76f42139.jpg")
plt.imshow(image)

# %%
image = cv2.imread(r"C:\Users\Lenovo\OneDrive\Desktop\f56d42ed91044f4b2e13746e76f42139.jpg")
image_new = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image_new)

# %%
image_gray = cv2.cvtColor(image_new, cv2.COLOR_BGR2GRAY)
plt.imshow(image_gray, cmap = plt.cm.gray)

# %%
new_image.quantize(2)
plt.imshow(new_image)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9908/558760276.py in <module>
# ----> 1 new_image.quantize(2)
#       2 plt.imshow(new_image)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'quantize'

# %%
img_flip1 = cv2.flip(new_image, 0)
plt.imshow(img_flip1)

# %%
img_flip2 = cv2.flip(new_image, 1)
plt.imshow(img_flip2)

# %%
img_rotate1 = cv2.rotate(new_image, cv2.ROTATE_90_CLOCKWISE)
plt.imshow(img_rotate1)

# %%
hist = cv2.calcHist([new_image], [0], None, [256], [0, 255])
plt.plot(hist)

# %%
img_neg = -1*new_image
plt.imshow(img_neg)

# %%
image_bright = cv2.convertScaleAbs(image_gray, alpha = -2, beta = 15)
plt.imshow(image_bright)

# %%
img_hist_equal = cv2.equalizeHist(image_gray)
plt.imshow(img_hist_equal)

# %%
hist2 = cv2.calcHist([img_hist_equal], [0], None, [256], [0, 255])
plt.plot(hist2)

# %%
ret, threshold_image = cv2.threshold(image_gray, 100, 255, cv2.THRESH_BINARY)
plt.imshow(threshold_image)
